# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/workspaces/CH-dataSience/data/Base.csv")
df.sample(10)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 32863            0     0.8               0.148214                         13
# 95635            0     0.9               0.361546                         56
# 231922           0     0.6               0.262839                         -1
# 214311           0     0.7               0.842241                         -1
# 197821           0     0.8               0.770504                         -1
# 171898           0     0.9               0.332605                         -1
# 108697           0     0.9               0.410290                         -1
# 181028           0     0.4               0.110551                         -1
# 100931           0     0.9               0.719524                         50
# 261520           0     0.3               0.929669                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# ...

# %% [markdown]
# Primera database, FRAUDE EN SOLICITUD DE CRÉDITO
# Columnas de interes para analizar y detectar solicitudes de crédito fraudlentas:
# -Columnas que hacen referencia a la victima (edad, income, mese sde antiguedad de la cuenta, limite de crédito, sistema operativo del que es usuario/a) para analizar cual es la moda de la con respecto a los rasgos buscados por el victimario
# -Detalles de solicitud y el crédito (dias desde el pedido, fuente, minutos de sesion activa, solicitado desde otro pais o no) para identificar patrones frecuentes en las solicitudes fraudulentas
# -Credito en si (tipo de pago) para analizar si hay un tipo de pago preferencial elegido para la ciber estafa

# %%
df2 = pd.read_csv("/workspaces/CH-dataSience/data/application_record.csv")
df2.sample(10)
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 231445  6126399           F            N               Y             0
# 74347   5282921           F            N               Y             3
# 283077  6124195           F            N               Y             0
# 298868  6189308           M            Y               Y             2
# 226282  5980867           F            N               Y             0
# 90249   5355636           M            Y               Y             0
# 13024   5139695           F            Y               Y             0
# 410030  6772960           M            Y               N             2
# 390949  6658954           F            N               Y             0
# 54728   5169366           M            Y               N             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 231445          135000.0             Pensioner  Secondary / secondary special
# ...

# %% [markdown]
# Segunda dataset SCORING CREDITICIO
# Columnas de interes para analizar scoring crediticio y grados de riesgo de otorgarun crédito/aprobar o reprobar una solicitud de crédito
# -ingresos anuales (AMT_INCOME_TOTAL) para analizar la posibilidad del pago del prestamo y naturaleza del ingreso (NAME_INCOME_TYPE) en orden a considerar la estabilidad del ingreso
# -estado civil (NAME_FAMILY_STATUS) para considerar si quien solicita el crédito tiene cargas de familia
# -Casa o apartamento (NAME_HOUSING_TYPE) para considerar gastos en los que se incurre en relacion al ingreso

# %%
df3 = pd.read_csv("/workspaces/CH-dataSience/data/dataset_phishing.csv")
df3.sample(10)
# Out:
#                                                      url  length_url  \
# 5792   https://www.scribd.com/doc/222372434/221127823...         157
# 6660                           http://smartusluga.xja.pl          25
# 10817      https://ccrma.stanford.edu/~matt/latencytest/          45
# 1216   http://www.inbioma.pe/rechnung-082325024299979...         162
# 5364     https://en.wikipedia.org/wiki/Numerical_control          47
# 1393                         http://www.petitcitron.com/          27
# 5108                           http://google.vipcentr.ru          25
# 7925                             https://www.isarms.com/          23
# 10450  https://ipa.edu.kh/wp-includes/SimplePie/XML/u...          61
# 922                 http://pentaho-bi-suite.blogspot.com          36
#
#        length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  \
# 5792                14   1        2          11      0      0       0      0
# ...

# %% [markdown]
# tercera dataset PHISHING WEBSITES
# Columnas de interes para analizar y detectar patrones de phishing webs para predecir si una web es sopechosa o no
# -largo del dominio web (length_url)
# -edad del dominio (domain_age) lo cual le da fiabildiad al mismo
# -si la pagina se encuentra en el indice de google o no (google_index)
# -la confirmacion si la pagina es legitima o es de phishing (status)
