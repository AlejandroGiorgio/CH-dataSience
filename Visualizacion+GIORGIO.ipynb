# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Para la segunda entrega se ha elegido trabajar con la dataset de Fraude en solicitud de crédito

# %%
df = pd.read_csv("/workspaces/CH-dataSience/data/Base.csv")
df.sample(10)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 148016           0     0.1               0.997074                         12
# 232589           0     0.9               0.715648                         -1
# 30594            0     0.8               0.493058                         32
# 138813           0     0.4               0.990531                         29
# 189541           0     0.2               0.857480                         -1
# 191901           0     0.9               0.368681                        309
# 149307           0     0.1               0.073961                         12
# 69278            0     0.8               0.097252                         61
# 255994           0     0.3               0.255927                         31
# 253726           0     0.1               0.295021                         37
#
#         current_address_months_count  customer_age  days_since_request  \
# ...

# %% [markdown]
# Graficos con MatPlotLib

# %%
#histograma para mostrar la frecuencia de la edad de la vitcima
df["customer_age"].plot(kind="hist", bins = 8, figsize= (14,6))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#Se aprecia que la mayor parte de las victimas 
#tiene entre 30 y 40 años

# %%
#grafico de torta para mostrar la distribucion de 
#el sistema operativo de la victima
df["device_os"].value_counts().plot(kind="pie", figsize=(6,6))
# Out:
# <AxesSubplot: ylabel='device_os'>

# %%
#se aprecia que macintosh es el OS cuyos usuarios son menos
#vulnerados
#Asi mismo Linux es el OS mas frecuente entre los usuarios
#que son vulnerados

# %%
#Grafico de densidad para identificar el limite crediticio
#mas usual de la victima
df["proposed_credit_limit"].plot(kind="kde", figsize = (14,6))
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
#Por el contrario de lo que indica el sentido comun
#las personas con un limite crediticio mas bajo (entre 0 a 500) 
#muestran mayor tendencia a ser victimas de una solicitud fraudulenta

# %% [markdown]
# GRAFICOS CON SEABORN

# %%
#Relacion entre la antiguedad de la cuenta y la duracion de la sesion en la que se solicito el crédito
#axislevel
sns.scatterplot(data=df, x="session_length_in_minutes", y="current_address_months_count", s=3)
plt.xlabel('Largo de sesion')
plt.ylabel('Antiguedad de cuenta')
# Out:
# Text(0, 0.5, 'Antiguedad de cuenta')

# %%
#Se aprecia una correlacion directa entre la duracion de la sesion y la antiguedad de la cuenta
#A mayor antiguedad de la cuenta y mayor duracion de la sesion menor fue la densidad de solicitud fraudulenta
#asi tambien, cuanto mas antigua la cuenta hay mas casos donde menos larga es la sesion 
#y cuanto mas nueva hay mas casos donde la sesion es mas extensa
