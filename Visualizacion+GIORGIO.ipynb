# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Para la segunda entrega se ha elegido trabajar con la dataset de Fraude en solicitud de crédito

# %%
df = pd.read_csv("/workspaces/CH-dataSience/data/Base.csv")
df.sample(10)
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 87616            0     0.8               0.142073                         -1
# 69489            0     0.7               0.954604                         -1
# 24301            0     0.7               0.586354                        103
# 99553            0     0.1               0.610490                         -1
# 260143           0     0.9               0.625984                         28
# 34771            0     0.3               0.290696                         -1
# 7596             0     0.8               0.040842                         -1
# 63302            0     0.7               0.893537                         -1
# 242717           0     0.1               0.733848                         29
# 53947            0     0.4               0.509497                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 87616                            159            20            0.006749
# 69489                              9            10            0.012885
# 24301                              6            20            0.001166
# 99553                             13            20            0.029917
# 260143                            10            30            0.026995
# 34771                            130            60            0.008007
# 7596                             268            70            0.035470
# 63302                            139            40            0.008546
# 242717                            10            40            0.020618
# 53947                             80            30            0.004690
#
#         intended_balcon_amount payment_type  zip_count_4w  ...  \
# 87616                -0.737373           AC           840  ...
# 69489                -0.754670           AC           518  ...
# 24301                99.601714           AD          1389  ...
# 99553                -0.811638           AB          1564  ...
# 260143               -0.713150           AB           881  ...
# 34771                -0.170740           AC           879  ...
# 7596                 34.290605           AA          1534  ...
# 63302                -0.579305           AC          1226  ...
# 242717               -0.816490           AC           775  ...
# 53947                -0.795843           AD          1188  ...
#
#         has_other_cards  proposed_credit_limit  foreign_request    source  \
# 87616               0.0                  200.0              0.0  INTERNET
# 69489               0.0                  200.0              0.0  INTERNET
# 24301               0.0                  200.0              0.0  INTERNET
# 99553               0.0                  200.0              0.0  INTERNET
# 260143              0.0                  200.0              0.0  INTERNET
# 34771               0.0                  200.0              0.0  INTERNET
# 7596                1.0                  500.0              0.0  INTERNET
# 63302               1.0                 1000.0              0.0  INTERNET
# 242717              0.0                  200.0              0.0  INTERNET
# 53947               0.0                  200.0              0.0  INTERNET
#
#         session_length_in_minutes device_os  keep_alive_session  \
# 87616                    1.034641     other                 0.0
# 69489                   15.171878     other                 0.0
# 24301                    1.759468     linux                 1.0
# 99553                    1.471650     linux                 1.0
# 260143                   5.558385   windows                 1.0
# 34771                    1.701742     linux                 0.0
# 7596                     1.881349   windows                 1.0
# 63302                    4.748937   windows                 1.0
# 242717                   2.153360   windows                 1.0
# 53947                    3.769360     linux                 0.0
#
#         device_distinct_emails_8w device_fraud_count  month
# 87616                         1.0                0.0    7.0
# 69489                         1.0                0.0    7.0
# 24301                         1.0                0.0    7.0
# 99553                         1.0                0.0    3.0
# 260143                        1.0                0.0    2.0
# 34771                         1.0                0.0    7.0
# 7596                          1.0                0.0    7.0
# 63302                         1.0                0.0    7.0
# 242717                        1.0                0.0    3.0
# 53947                         1.0                0.0    7.0
#
# [10 rows x 32 columns]
