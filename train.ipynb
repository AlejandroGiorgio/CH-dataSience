# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv("/workspaces/CH-dataSience/data/casos_covid19_2020.csv")
df
# Out:
# /tmp/ipykernel_7714/2108176302.py:1: DtypeWarning: Columns (10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/workspaces/CH-dataSience/data/casos_covid19_2020.csv")
#         numero_de_caso fecha_apertura_snvs fecha_toma_muestra  \
# 0              4742251           26-Nov-20          22-Dec-20
# 1              2025629           21-Aug-20          21-Aug-20
# 2              4964824            3-Dec-20           3-Dec-20
# 3              4986600            4-Dec-20           3-Dec-20
# 4              4987906            4-Dec-20          17-Dec-20
# ...                ...                 ...                ...
# 573327         2867864           24-Sep-20          24-Sep-20
# 573328         2869673           24-Sep-20          20-Sep-20
# 573329         2612530           14-Sep-20          14-Sep-20
# 573330         2612577           14-Sep-20          14-Sep-20
# 573331         3168144            6-Oct-20          28-Dec-21
#
# ...

# %%
df2 = pd.read_csv("/workspaces/CH-dataSience/data/Amazon Sale Report.csv")
df2.sample(10)
df2.info
# Out:
# /tmp/ipykernel_7714/1218057772.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("/workspaces/CH-dataSience/data/Amazon Sale Report.csv")
# <bound method DataFrame.info of          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545  4/30/2022                     Cancelled
# 1            1  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  4/30/2022                       Shipped
# 3            3  403-9615377-8133951  4/30/2022                     Cancelled
# 4            4  407-1069790-7240320  4/30/2022                       Shipped
# ...        ...                  ...        ...                           ...
# 128970  128970  406-6001380-7673107  5/31/2022                       Shipped
# 128971  128971  402-9551604-7544318  5/31/2022                       Shipped
# ...
